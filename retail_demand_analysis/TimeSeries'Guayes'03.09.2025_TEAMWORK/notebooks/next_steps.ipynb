# %% [markdown]
# # NEXT STEPS

# %% [markdown]
# - Jedes Modellpattern mit einem Baseline Model Predicten

# %% [markdown]
# daily_smooth: Store x Item y ; Baselinemodell (XG Boost, SARIMA)
# daily_erratic: Store x Item y ;  Baselinemodell (XG Boost, SARIMA)
# weekly_smooth: Store x Item y ;  Baselinemodell (XG Boost, SARIMA)
# weekly_erratic: Store x Item y ;  Baselinemodell (XG Boost, SARIMA)

# %% [markdown]
# Jede Serie: Ausreisser ? Features lags (1, 3, 7)
#
#
# Für jede Serie:
# 	1.	STL Decomposition
# 	2.	ACF / PACF
# 	3.	Stationarity Test
# 	4.	Seasonality detection
# 	5.	Baseline wählen:
#
#     Struktur        Modell
#     AR-dominiert    ARIMA
#     saisonal        SARIMA
#     wenig Struktur  Moving Average
#     intermittent    Croston

# %% [markdown]
# Split (nur die Train Daten - kein data leakage)
#
#
# - r2 mit einbinden (sagt uns ob das modell richtig gelernt hat (negative werte sind schlecht))
# - Github freigabe für Krupesh
# - baseline nochmal neu

# %% [markdown]
# - SARIMAX und GRADIEN BOOST als nächste Modelle
# - zusätzl. Features Definieren
# - Sarima : p,d,q Werte ausprobieren
