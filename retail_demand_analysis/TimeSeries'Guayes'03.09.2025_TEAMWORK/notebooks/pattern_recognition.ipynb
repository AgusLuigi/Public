# %%
import os
from pathlib import Path

# %%
print("Current working directory:", os.getcwd())

PROJECT_ROOT = Path("..").resolve()

# Setze das Arbeitsverzeichnis auf das Hauptprojektverzeichnis
os.chdir(f"{PROJECT_ROOT}")

# Überprüfe, ob das Verzeichnis korrekt gesetzt wurde
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/kiko/Desktop/github/Group-Work-Favorita-Forecasting/notebooks
# Current working directory: /Users/kiko/Desktop/github/Group-Work-Favorita-Forecasting

# %%
from Favorita_TSA.models.data_preparation import build_dataframes

dfs = build_dataframes()

df_smooth_daily = dfs["smooth_daily"]  # Smooth  aus daily  Matrix
df_erratic_daily = dfs["erratic_daily"]  # Erratic aus daily  Matrix
df_smooth_weekly = dfs["smooth_weekly"]  # Smooth  aus weekly Matrix
df_erratic_weekly = dfs["erratic_weekly"]  # Erratic aus weekly Matrix
# Out:
# Loading fact table …
# Loading forecastability matrices …
# Building DataFrames …
#   smooth_daily         36,560 store-item pairs     39,523,827 rows
#   erratic_daily        35,933 store-item pairs     36,705,401 rows
#   smooth_weekly        47,196 store-item pairs     30,042,814 rows
#   erratic_weekly       19,734 store-item pairs     10,182,367 rows

# %%
df_smooth_daily.head()
# Out:
#     id       date  store_nbr  item_nbr  unit_sales  onpromotion  year  dow  \
# 0   12 2013-01-01         25    115611         1.0         <NA>  2013    1
# 1   64 2013-01-01         25    215352        46.0         <NA>  2013    1
# 2   76 2013-01-01         25    252970         3.0         <NA>  2013    1
# 3   86 2013-01-01         25    261700         3.0         <NA>  2013    1
# 4  103 2013-01-01         25    305080        10.0         <NA>  2013    1
#
#    year_iso  week week_start      month
# 0      2013     1 2012-12-31 2013-01-01
# 1      2013     1 2012-12-31 2013-01-01
# 2      2013     1 2012-12-31 2013-01-01
# 3      2013     1 2012-12-31 2013-01-01
# 4      2013     1 2012-12-31 2013-01-01

# %%
from Favorita_TSA.preprocess.holiday_parquets import save_holiday_enriched_tables

save_holiday_enriched_tables(scope_days=5)
# Out:
# /Users/patrickhederer/Python Projects/Group-Work-Favorita-Forecasting/src/Favorita_TSA/preprocess/holiday_parquets.py:77: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out[c] = out[c].fillna(False).astype(bool)
# /Users/patrickhederer/Python Projects/Group-Work-Favorita-Forecasting/src/Favorita_TSA/preprocess/holiday_parquets.py:77: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out[c] = out[c].fillna(False).astype(bool)
# /Users/patrickhederer/Python Projects/Group-Work-Favorita-Forecasting/src/Favorita_TSA/preprocess/holiday_parquets.py:77: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out[c] = out[c].fillna(False).astype(bool)
# /Users/patrickhederer/Python Projects/Group-Work-Favorita-Forecasting/src/Favorita_TSA/preprocess/holiday_parquets.py:133: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out[c] = out[c].fillna(False).astype(bool)
# /Users/patrickhederer/Python Projects/Group-Work-Favorita-Forecasting/src/Favorita_TSA/preprocess/holiday_parquets.py:133: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out[c] = out[c].fillna(False).astype(bool)
# /Users/patrickhederer/Python Projects/Group-Work-Favorita-Forecasting/src/Favorita_TSA/preprocess/holiday_parquets.py:133: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out[c] = out[c].fillna(False).astype(bool)
# ✅ Holiday parquet tables saved:
#    - store_item_daily_holiday.parquet
#    - store_item_weekly_holiday.parquet
